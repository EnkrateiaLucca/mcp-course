# %% [markdown]
# # Introduction to AI Agents — Building a Research Assistant from Scratch
#
# This notebook builds a small **personal research assistant** with the Claude API, going from zero to a complete agentic loop.
#
# By the end of the notebook the same use case (web search + filesystem) will follow us through the rest of the course: in demo `01` we will expose these tools through an **MCP server**, and in demo `02` we will rebuild the agent on top of the **Claude Agent SDK**.
#
# ## What is an Agent?
#
# An AI agent is a system where an LLM can:
# 1. Decide which tools/functions to call
# 2. Execute those tools
# 3. Use the results to take further actions
# 4. Continue until the task is complete

# %% [markdown]
# > ### 📝 Presenter notes — July 2026 refresh (module 00 kept as-is by design)
# >
# > This module stays **loop-first on purpose**: Anthropic's own tool-use tutorial still teaches the hand-rolled loop before abstracting it away, and it's what separates this course from SDK-only crash courses. Suggested tightening for live delivery:
# >
# > - **Compress, don't cut**: show ~40 lines of the loop on screen (tool defs can be skimmed), target ~25 min.
# > - **New middle rung (optional 2-min aside)**: the Claude API now ships a beta `client.beta.messages.tool_runner(...)` that runs this exact loop over your own tools — the official bridge between "loop by hand" and the Agent SDK. Docs: https://platform.claude.com/docs/en/agents-and-tools/tool-use/tool-runner
# > - **End beat**: "this loop is now infrastructure — Tool Runner, the Agent SDK — but you now know what's inside it." Then straight into module 01: *the tools move out of the process.*
# > - The course-wide arc this feeds: loop → MCP server (01) → Agent SDK host (02) → skills (03) → production (04) → deploy + MCP Apps (05) → security & composition (06).

# %% [markdown]
# ![](2025-11-05-14-23-10.png)

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"var: ")

_set_env("ANTHROPIC_API_KEY")

# %%
# Setup
# Install once: pip install anthropic ddgs python-dotenv
import os
import json
from pathlib import Path
from anthropic import Anthropic

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

# %%
from IPython.display import Markdown
response = client.messages.create(
    model="claude-sonnet-5",
    max_tokens=256,
    messages=[
        {"role": "user", "content": "Hello Claude! What can you do as an agent?"}
    ]
)
Markdown(response.content[0].text)
# Out:
# # Hello! Here's what I can do as an agent
#
# As Claude, I can act as an agent to help you accomplish multi-step tasks, especially when connected to tools and external systems. Here's an overview:
#
# ## Core Agentic Capabilities
#
# **Task Planning & Execution**
# - Break down complex goals into manageable steps
# - Work through multi-step processes while maintaining context
# - Adapt my approach based on intermediate results
#
# **Tool Use** (when available in your environment)
# - Web search and browsing for current information
# - Code execution (writing, running, and debugging code)
# - File operations (reading, writing, editing documents)
# - API calls to interact with external services
# - Using specialized tools you've configured (calculators, databases, etc.)
#
# **Reasoning Through Problems**
# - Analyze situ

# %% [markdown]
# ## Step 1: The Tools
#
# A research assistant needs two kinds of capabilities:
#
# - **Web search** — to find information on the internet.
# - **Filesystem + shell** — to save notes, organize findings, and run quick commands. We mirror the classic coding-agent toolset: `read`, `write`, `edit`, and `bash`.
#
# We use [`ddgs`](https://pypi.org/project/ddgs/) for search because it requires **no API key** — perfect for a from-scratch demo. The file tools are constrained to a single `workspace/` directory, and the `bash` tool runs with `cwd=workspace/` so the agent operates inside the sandbox.

# %%
# Sandbox: every file the agent touches lives inside ./workspace
WORKSPACE = Path("./workspace").resolve()
WORKSPACE.mkdir(exist_ok=True)

def _safe(path: str) -> Path:
    """Resolve a user-supplied path inside WORKSPACE, blocking traversal."""
    p = (WORKSPACE / path).resolve()
    if WORKSPACE not in p.parents and p != WORKSPACE:
        raise ValueError(f"Path escapes workspace: {path}")
    return p

# %%
import subprocess
from ddgs import DDGS

def web_search(query: str, max_results: int = 5) -> str:
    """Search the web with DuckDuckGo and return a compact JSON of hits."""
    hits = DDGS().text(query, max_results=max_results)
    trimmed = [
        {"title": h.get("title"), "url": h.get("href"), "snippet": h.get("body")}
        for h in hits
    ]
    return json.dumps(trimmed, indent=2)

def read_file(path: str) -> str:
    return _safe(path).read_text()

def write_file(path: str, content: str) -> str:
    p = _safe(path)
    p.parent.mkdir(parents=True, exist_ok=True)
    p.write_text(content)
    return f"Wrote {len(content)} chars to {path}"

def edit_file(path: str, old: str, new: str) -> str:
    p = _safe(path)
    text = p.read_text()
    if old not in text:
        return f"Error: substring not found in {path}"
    p.write_text(text.replace(old, new))
    return f"Edited {path}"

def run_bash(command: str) -> str:
    """Run a shell command inside the workspace sandbox and return its output."""
    result = subprocess.run(
        command,
        shell=True,
        cwd=WORKSPACE,
        capture_output=True,
        text=True,
        timeout=30,
    )
    output = (result.stdout + result.stderr).strip()
    return output or f"(exit code {result.returncode}, no output)"

# Quick smoke test
print(write_file("hello.md", "# hi\n"))
print(run_bash("ls"))
print(read_file("hello.md"))
# Out:
# Wrote 5 chars to hello.md
# hello.md
# notes
# research
# workspace-stats.txt
# # hi

# %% [markdown]
# ## Step 2: Define Tools for LLM

# %% [markdown]
# ### Primer on Tool Calling
#
# Before we use Claude's native tool-use API, let's see what tool calling *actually* is: just an LLM emitting a structured string that we parse and execute.

# %% [markdown]
# ![](2026-01-21-14-17-46.png)

# %%
# A 'from scratch' tool call: ask Claude to emit a function call as plain text
user_input = "Find me three recent articles about the Model Context Protocol."
response = client.messages.create(
    model="claude-sonnet-5",
    max_tokens=256,
    messages=[
        {"role": "user", "content": f"""
         You are a research assistant with access to a 'web_search' function:
         
             web_search(query: str, max_results: int) -> str
         
         When the user asks for information, your ENTIRE output must be a single tool call
         wrapped in square brackets, like: [web_search(query="...", max_results=3)]
         
         User: {user_input}
         """}
    ]
)
print(response.content[0].text)
# Out:
# [web_search(query="Model Context Protocol", max_results=3)]

# %% [markdown]
# That works, but it is fragile: we'd have to write a parser, handle malformed output, and the LLM has no schema to follow. Claude's native **tool use** API solves all of this — we describe the tools with JSON schemas and Claude emits structured `tool_use` blocks.

# %%
tools = [
    {
        "name": "web_search",
        "description": "Search the web with DuckDuckGo. Returns a JSON list of {title, url, snippet}.",
        "input_schema": {
            "type": "object",
            "properties": {
                "query": {"type": "string", "description": "Search query"},
                "max_results": {"type": "integer", "description": "How many results to return", "default": 5}
            },
            "required": ["query"]
        }
    },
    {
        "name": "read",
        "description": "Read a text file from the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {"path": {"type": "string"}},
            "required": ["path"]
        }
    },
    {
        "name": "write",
        "description": "Create or overwrite a file in the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {
                "path": {"type": "string"},
                "content": {"type": "string"}
            },
            "required": ["path", "content"]
        }
    },
    {
        "name": "edit",
        "description": "Replace a substring in an existing file.",
        "input_schema": {
            "type": "object",
            "properties": {
                "path": {"type": "string"},
                "old": {"type": "string", "description": "Exact substring to replace"},
                "new": {"type": "string", "description": "Replacement text"}
            },
            "required": ["path", "old", "new"]
        }
    },
    {
        "name": "bash",
        "description": (
            "Run a shell command inside the workspace directory and return its output. "
            "Use it to list, move, delete, or inspect files (ls, mv, rm, mkdir, wc, grep, cat...)."
        ),
        "input_schema": {
            "type": "object",
            "properties": {
                "command": {"type": "string", "description": "The shell command to run"}
            },
            "required": ["command"]
        }
    }
]

available_functions = {
    "web_search": web_search,
    "read": read_file,
    "write": write_file,
    "edit": edit_file,
    "bash": run_bash,
}

# %% [markdown]
# ## Step 3: Single Tool Call Example
#
# Let's see Claude decide to call a tool, then execute it ourselves and feed the result back.

# %%
messages = [
    {"role": "user", "content": "Search the web for: 'what is the Model Context Protocol' (3 results)."}
]

response = client.messages.create(
    model="claude-sonnet-5",
    max_tokens=1024,
    messages=messages,
    tools=tools,
)

print("Stop reason:", response.stop_reason)
for block in response.content:
    print(block)
# Out:
# Stop reason: tool_use
# ToolUseBlock(id='toolu_0186H9Vz2YrTcvjWSf6GHhVY', input={'query': 'what is the Model Context Protocol', 'max_results': 3}, name='web_search', type='tool_use', caller={'type': 'direct'})

# %%
if response.stop_reason == "tool_use":
    messages.append({"role": "assistant", "content": response.content})
    tool_results = []
    for block in response.content:
        if block.type == "tool_use":
            print(f"-> {block.name}({block.input})")
            result = available_functions[block.name](**block.input)
            tool_results.append({
                "type": "tool_result",
                "tool_use_id": block.id,
                "content": str(result),
            })
    messages.append({"role": "user", "content": tool_results})

    final = client.messages.create(
        model="claude-sonnet-5",
        max_tokens=1024,
        messages=messages,
        tools=tools,
    )
    print("\nClaude:", "".join(b.text for b in final.content if hasattr(b, "text")))
# Out:
# -> web_search({'query': 'what is the Model Context Protocol', 'max_results': 3})
#
# Claude: Here are 3 results for "what is the Model Context Protocol":
#
# 1. **Model Context Protocol (Official Docs)**
#    URL: https://modelcontextprotocol.io/docs/getting-started/intro
#    MCP is an open-source standard for connecting AI applications to external systems, allowing AI apps like Claude or ChatGPT to interact with outside data sources and tools.
#
# 2. **Introducing the Model Context Protocol — Anthropic**
#    URL: https://www.anthropic.com/news/model-context-protocol
#    (Nov 25, 2024) Describes MCP as an open standard enabling developers to build secure, two-way connections between data sources and AI-powered tools.
#
# 3. **What is Model Context Protocol (MCP)? A guide — Google Cloud**
#    URL: https://cloud.google.com/discover/what-is-model-context-protocol
# ...

# %% [markdown]
# ## Step 4: The Agent Loop
#
# Real tasks need *several* tool calls. The agent loop is the simplest possible pattern: keep calling Claude with the growing message history until it stops asking for tools.

# %%
SYSTEM = (
    "You are a personal research assistant. You can search the web and "
    "organize findings as files in the user's workspace. "
    "When asked to 'research X', search the web, then save a short markdown "
    "brief with sources. Keep filenames lowercase-hyphenated."
)

def run_agent(user_query: str, max_iterations: int = 10) -> str:
    messages = [{"role": "user", "content": user_query}]
    print(f"User: {user_query}\n")

    for i in range(max_iterations):
        response = client.messages.create(
            model="claude-sonnet-5",
            max_tokens=2048,
            system=SYSTEM,
            messages=messages,
            tools=tools,
        )

        if response.stop_reason != "tool_use":
            text = "".join(b.text for b in response.content if hasattr(b, "text"))
            print(f"Agent (final): {text}")
            return text

        messages.append({"role": "assistant", "content": response.content})
        tool_results = []
        for block in response.content:
            if block.type == "tool_use":
                print(f"  [{i+1}] {block.name}({json.dumps(block.input)[:120]})")
                try:
                    result = available_functions[block.name](**block.input)
                except Exception as e:
                    result = f"Error: {e}"
                tool_results.append({
                    "type": "tool_result",
                    "tool_use_id": block.id,
                    "content": str(result),
                })
        messages.append({"role": "user", "content": tool_results})

    return "(max iterations reached)"

# %% [markdown]
# ## Step 5: Research Assistant in Action
#
# Now we hand the agent a real research task. It should search, then write a brief into the workspace.

# %%
run_agent(
    "Research what the Model Context Protocol is and why it matters. "
    "Save a short markdown brief to research/mcp-brief.md with 3-5 bullet points and a sources list."
)
# Out:
# User: Research what the Model Context Protocol is and why it matters. Save a short markdown brief to research/mcp-brief.md with 3-5 bullet points and a sources list.
#
#   [1] web_search({"query": "Model Context Protocol MCP"})
#   [1] web_search({"query": "Model Context Protocol why it matters AI agents"})
#   [2] bash({"command": "mkdir -p research"})
#   [2] write({"path": "research/mcp-brief.md", "content": "# Model Context Protocol (MCP) \u2014 Research Brief\n\n- **What it is:** )
# Agent (final): Saved the brief to `research/mcp-brief.md`. Summary:
#
# **Model Context Protocol (MCP)** is an open standard introduced by Anthropic (Nov 2024) that standardizes how AI models connect to external tools and data sources — often described as "USB-C for AI." Key points covered in the brief:
#
# - What it is and who created it
# - How it works (common protocol layer replacing custom integrations)
# - Why it matters for building reliable, tool-using AI agents
# ...

# %%
# Inspect what the agent produced
print(run_bash("find . -type f | sort"))
print("\n---\n")
print(read_file("research/mcp-brief.md"))
# Out:
# ./hello.md
# ./notes/mcp.md
# ./research/mcp-brief.md
#
# ---
#
# # Model Context Protocol (MCP) — Research Brief
#
# - **What it is:** MCP is an open standard/open-source framework introduced by Anthropic in November 2024 that standardizes how AI systems (like LLMs) connect to and exchange data with external tools, systems, and data sources (e.g., Google Drive, Slack, GitHub, databases).
#
# - **How it works:** MCP acts as a common protocol layer — similar to a "USB-C for AI" — so instead of building custom, one-off integrations between each model and each tool/data source, developers implement MCP once and it works across compatible clients and servers.
#
# - **Why it matters for AI agents:** It enables AI assistants and agents to dynamically discover, select, and call external tools/data at runtime rather than relying on hard-coded integrations, which is essential for moving from simple chatbots to reliable, multi-step, tool-using agents.
#
# ...

# %% [markdown]
# ## Step 6: A Reorganization Task
#
# Anything an agent can save, it can also rearrange. Watch it combine `bash` (for `mv` / `rm` / `mkdir`) with `edit` on the same task.

# %%
run_agent(
    "Rename research/mcp-brief.md to notes/mcp.md, add a '## TL;DR' section at the top, "
    "and remove the research/ folder if it's now empty."
)
# Out:
# User: Rename research/mcp-brief.md to notes/mcp.md, add a '## TL;DR' section at the top, and remove the research/ folder if it's now empty.
#
#   [1] bash({"command": "ls -la research/ 2>&1; echo \"---\"; cat research/mcp-brief.md 2>&1"})
#   [2] bash({"command": "mkdir -p notes && mv research/mcp-brief.md notes/mcp.md && rmdir research 2>&1; ls -la"})
#   [3] edit({"path": "notes/mcp.md", "old": "# Model Context Protocol (MCP) \u2014 Research Brief", "new": "# Model Context Protocol)
# Agent (final): Done:
#
# - Moved `research/mcp-brief.md` → `notes/mcp.md`
# - Added a `## TL;DR` section at the top summarizing the brief
# - Removed the now-empty `research/` folder
# 'Done:\n\n- Moved `research/mcp-brief.md` → `notes/mcp.md`\n- Added a `## TL;DR` section at the top summarizing the brief\n- Removed the now-empty `research/` folder'

# %% [markdown]
# ## Step 7: Triggering the `bash` Tool
#
# Some tasks are awkward with pure file tools but trivial in a shell — counting words, grepping, building directory trees. A prompt that asks for this kind of inspection pushes the agent straight to `bash`.

# %%
# A prompt designed to trigger the bash tool
run_agent(
    "Use bash to inspect the workspace: show a file tree, count the words in notes/mcp.md, "
    "and count how many URLs (lines containing 'http') appear in it. "
    "Then write a one-line summary of those stats to workspace-stats.txt."
)
# Out:
# User: Use bash to inspect the workspace: show a file tree, count the words in notes/mcp.md, and count how many URLs (lines containing 'http') appear in it. Then write a one-line summary of those stats to workspace-stats.txt.
#
#   [1] bash({"command": "echo \"=== FILE TREE ===\"; find . -not -path './.git*' | sort; echo; echo \"=== FILE CHECK ===\"; ls -la n)
#   [2] bash({"command": "echo \"=== WORD COUNT ===\"; wc -w notes/mcp.md; echo; echo \"=== URL LINES ===\"; grep -c 'http' notes/mcp)
#   [3] write({"path": "workspace-stats.txt", "content": "Workspace contains 2 files (hello.md, notes/mcp.md); notes/mcp.md has 332 wo)
# Agent (final): Here's the workspace inspection summary:
#
# **File tree:**
# ```
# .
# ./hello.md
# ./notes
# ./notes/mcp.md
# ```
#
# **Stats for `notes/mcp.md`:**
# - Word count: **332 words**
# - Lines containing URLs (`http`): **5**
#
# ...

# %% [markdown]
# ## Key Takeaways
#
# 1. **Tool calling** is just Claude emitting structured `tool_use` blocks given JSON-schema tool definitions.
# 2. **Tool execution** happens on *our* side — we run the function and pass results back as `tool_result` blocks.
# 3. **The agent loop** is small: keep calling Claude with the growing message history until `stop_reason != "tool_use"`.
# 4. **Same use case forward** — in demo `01` we'll wrap these exact tools as an **MCP server** so any host (Claude Desktop, our own client, the Agent SDK) can use them. In demo `02` we rebuild the agent loop on the **Claude Agent SDK** and plug the MCP server in.
#
# ### What MCP will buy us
#
# Right now the tools and the agent live in the same Python file. That's fine for a notebook, but it doesn't scale: every new client has to reimplement the tools. MCP standardizes this — *one* server, *many* hosts.
