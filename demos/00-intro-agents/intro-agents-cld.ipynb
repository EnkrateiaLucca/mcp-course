# %% [markdown]
# # Introduction to AI Agents — Building a Research Assistant from Scratch
#
# This notebook builds a small **personal research assistant** with the Claude API, going from zero to a complete agentic loop.
#
# By the end of the notebook the same use case (web search + filesystem) will follow us through the rest of the course: in demo `01` we will expose these tools through an **MCP server**, and in demo `02` we will rebuild the agent on top of the **Claude Agent SDK**.
#
# ## What is an Agent?
#
# An AI agent is a system where an LLM can:
# 1. Decide which tools/functions to call
# 2. Execute those tools
# 3. Use the results to take further actions
# 4. Continue until the task is complete

# %% [markdown]
# ![](2025-11-05-14-23-10.png)

# %%
import os
import getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"var: ")

_set_env("ANTHROPIC_API_KEY")

# %%
# Setup
# Install once: pip install anthropic ddgs python-dotenv
import os
import json
from pathlib import Path
from anthropic import Anthropic

client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

# %%
response = client.messages.create(
    model="claude-sonnet-4-6",
    max_tokens=256,
    messages=[
        {"role": "user", "content": "Hello Claude! What can you do as an agent?"}
    ]
)
print(response.content[0].text)
# Out:
# Hello! Great question. Here's an overview of what I can do:
#
# ## Core Capabilities
#
# **Writing & Communication**
# - Draft emails, essays, reports, creative writing
# - Editing, proofreading, summarizing
#
# **Analysis & Research**
# - Break down complex topics
# - Analyze data, arguments, or documents
# - Compare options and provide recommendations
#
# **Coding & Technical Help**
# - Write, debug, and explain code
# - Help with various programming languages
# - Technical documentation
#
# **Math & Reasoning**
# - Solve math problems
# - Work through logical problems step-by-step
#
# **Learning & Explanation**
# - Explain concepts at any level
# - Answer questions across many subjects
#
# ## As an "Agent" Specifically
# If given tools, I can:
# - 🔍 Search the web
# - 📁 Read/write files
# - 💻 Execute code
# - 🔗 Interact with APIs
# - 🔄 Complete multi-step tasks autonomously
#
# ## Honest Limitations
# - My knowledge has a **training cutoff**
# - I can't browse the web *unless given that tool*
# - I

# %% [markdown]
# ## Step 1: The Tools
#
# A research assistant needs two kinds of capabilities:
#
# - **Web search** — to find information on the internet.
# - **Filesystem** — to save notes, organize findings, edit/move/delete files.
#
# We use [`ddgs`](https://pypi.org/project/ddgs/) for search because it requires **no API key** — perfect for a from-scratch demo. The filesystem tools are constrained to a single `workspace/` directory so the agent cannot wander outside it.

# %%
# Sandbox: every file the agent touches lives inside ./workspace
WORKSPACE = Path("./workspace").resolve()
WORKSPACE.mkdir(exist_ok=True)

def _safe(path: str) -> Path:
    """Resolve a user-supplied path inside WORKSPACE, blocking traversal."""
    p = (WORKSPACE / path).resolve()
    if WORKSPACE not in p.parents and p != WORKSPACE:
        raise ValueError(f"Path escapes workspace: {path}")
    return p

# %%
from ddgs import DDGS

def web_search(query: str, max_results: int = 5) -> str:
    """Search the web with DuckDuckGo and return a compact JSON of hits."""
    hits = DDGS().text(query, max_results=max_results)
    trimmed = [
        {"title": h.get("title"), "url": h.get("href"), "snippet": h.get("body")}
        for h in hits
    ]
    return json.dumps(trimmed, indent=2)

def read_file(path: str) -> str:
    return _safe(path).read_text()

def write_file(path: str, content: str) -> str:
    p = _safe(path)
    p.parent.mkdir(parents=True, exist_ok=True)
    p.write_text(content)
    return f"Wrote {len(content)} chars to {path}"

def edit_file(path: str, old: str, new: str) -> str:
    p = _safe(path)
    text = p.read_text()
    if old not in text:
        return f"Error: substring not found in {path}"
    p.write_text(text.replace(old, new))
    return f"Edited {path}"

def move_file(src: str, dst: str) -> str:
    s, d = _safe(src), _safe(dst)
    d.parent.mkdir(parents=True, exist_ok=True)
    s.rename(d)
    return f"Moved {src} -> {dst}"

def delete_file(path: str) -> str:
    _safe(path).unlink()
    return f"Deleted {path}"

def list_files(directory: str = ".") -> str:
    base = _safe(directory)
    return "\n".join(sorted(str(p.relative_to(WORKSPACE)) for p in base.rglob("*"))) or "(empty)"

# Quick smoke test
print(write_file("hello.md", "# hi\n"))
print(list_files("."))
print(read_file("hello.md"))
# Out:
# Wrote 5 chars to hello.md
# hello.md
# # hi

# %% [markdown]
# ## Step 2: Define Tools for Claude

# %% [markdown]
# ### Primer on Tool Calling
#
# Before we use Claude's native tool-use API, let's see what tool calling *actually* is: just an LLM emitting a structured string that we parse and execute.

# %% [markdown]
# ![](2026-01-21-14-17-46.png)

# %%
# A 'from scratch' tool call: ask Claude to emit a function call as plain text
user_input = "Find me three recent articles about the Model Context Protocol."
response = client.messages.create(
    model="claude-sonnet-4-6",
    max_tokens=256,
    messages=[
        {"role": "user", "content": f"""
         You are a research assistant with access to a 'web_search' function:
         
             web_search(query: str, max_results: int) -> str
         
         When the user asks for information, your ENTIRE output must be a single tool call
         wrapped in square brackets, like: [web_search(query="...", max_results=3)]
         
         User: {user_input}
         """}
    ]
)
print(response.content[0].text)
# Out:
# [web_search(query="Model Context Protocol recent articles 2024", max_results=3)]

# %% [markdown]
# That works, but it is fragile: we'd have to write a parser, handle malformed output, and the LLM has no schema to follow. Claude's native **tool use** API solves all of this — we describe the tools with JSON schemas and Claude emits structured `tool_use` blocks.

# %%
tools = [
    {
        "name": "web_search",
        "description": "Search the web with DuckDuckGo. Returns a JSON list of {title, url, snippet}.",
        "input_schema": {
            "type": "object",
            "properties": {
                "query": {"type": "string", "description": "Search query"},
                "max_results": {"type": "integer", "description": "How many results to return", "default": 5}
            },
            "required": ["query"]
        }
    },
    {
        "name": "read_file",
        "description": "Read a text file from the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {"path": {"type": "string"}},
            "required": ["path"]
        }
    },
    {
        "name": "write_file",
        "description": "Create or overwrite a file in the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {
                "path": {"type": "string"},
                "content": {"type": "string"}
            },
            "required": ["path", "content"]
        }
    },
    {
        "name": "edit_file",
        "description": "Replace a substring in an existing file.",
        "input_schema": {
            "type": "object",
            "properties": {
                "path": {"type": "string"},
                "old": {"type": "string", "description": "Exact substring to replace"},
                "new": {"type": "string", "description": "Replacement text"}
            },
            "required": ["path", "old", "new"]
        }
    },
    {
        "name": "move_file",
        "description": "Move or rename a file inside the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {"src": {"type": "string"}, "dst": {"type": "string"}},
            "required": ["src", "dst"]
        }
    },
    {
        "name": "delete_file",
        "description": "Delete a file from the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {"path": {"type": "string"}},
            "required": ["path"]
        }
    },
    {
        "name": "list_files",
        "description": "List files under a directory in the workspace.",
        "input_schema": {
            "type": "object",
            "properties": {"directory": {"type": "string", "default": "."}},
            "required": []
        }
    }
]

available_functions = {
    "web_search": web_search,
    "read_file": read_file,
    "write_file": write_file,
    "edit_file": edit_file,
    "move_file": move_file,
    "delete_file": delete_file,
    "list_files": list_files,
}

# %% [markdown]
# ## Step 3: Single Tool Call Example
#
# Let's see Claude decide to call a tool, then execute it ourselves and feed the result back.

# %%
messages = [
    {"role": "user", "content": "Search the web for: 'what is the Model Context Protocol' (3 results)."}
]

response = client.messages.create(
    model="claude-sonnet-4-6",
    max_tokens=1024,
    messages=messages,
    tools=tools,
)

print("Stop reason:", response.stop_reason)
for block in response.content:
    print(block)
# Out:
# Stop reason: tool_use
# TextBlock(citations=None, text='Sure! Let me search the web for that right away.', type='text')
# ToolUseBlock(id='toolu_01EhaaGQE3zqWc9D7TNJLVpH', input={'query': 'what is the Model Context Protocol', 'max_results': 3}, name='web_search', type='tool_use', caller={'type': 'direct'})

# %%
if response.stop_reason == "tool_use":
    messages.append({"role": "assistant", "content": response.content})
    tool_results = []
    for block in response.content:
        if block.type == "tool_use":
            print(f"-> {block.name}({block.input})")
            result = available_functions[block.name](**block.input)
            tool_results.append({
                "type": "tool_result",
                "tool_use_id": block.id,
                "content": str(result),
            })
    messages.append({"role": "user", "content": tool_results})

    final = client.messages.create(
        model="claude-sonnet-4-6",
        max_tokens=1024,
        messages=messages,
        tools=tools,
    )
    print("\nClaude:", "".join(b.text for b in final.content if hasattr(b, "text")))
# Out:
# -> web_search({'query': 'what is the Model Context Protocol', 'max_results': 3})
#
# Claude: Here are the top 3 search results for **"What is the Model Context Protocol"**:
#
# ---
#
# 1. 🔵 **[Model Context Protocol - Wikipedia](https://en.wikipedia.org/wiki/Model_Context_Protocol)**
#    > MCP provides a standardized interface for reading files, executing functions, and handling contextual prompts. Following its announcement, the protocol was adopted by major AI providers, including OpenAI and Google DeepMind. MCP was announced by Anthropic in November 2024 as an open standard.
#
# ---
#
# 2. 🟢 **[What is the Model Context Protocol (MCP)? - modelcontextprotocol.io](https://modelcontextprotocol.io/docs/getting-started/intro)**
#    > MCP (Model Context Protocol) is an open-source standard for connecting AI applications to external systems. Using MCP, AI applications like Claude or ChatGPT can connect to external tools and data sources.
#
# ---
#
# 3. 🟠 **[What Is the Model Context Protocol (MCP) and How It Works - Descope](https://www.descope.com/learn/post/mcp)**
#    > MCP is the open source protocol developed by Anthropic to provide LLMs and AI agents a standardized way to connect with external data sources and tools.
#
# ---
#
# ### 📝 Summary:
# The **Model Context Protocol (MCP)** is an **open-source standard** introduced by **Anthropic in November 2024**. It provides a **standardized way for AI applications** (like Claude or ChatGPT) to connect with **external data sources, tools, and systems** — enabling actions like reading files, executing functions, and handling contextual prompts. It has since been adopted by major AI providers including **OpenAI** and **Google DeepMind**.

# %% [markdown]
# ## Step 4: The Agent Loop
#
# Real tasks need *several* tool calls. The agent loop is the simplest possible pattern: keep calling Claude with the growing message history until it stops asking for tools.

# %%
SYSTEM = (
    "You are a personal research assistant. You can search the web and "
    "organize findings as files in the user's workspace. "
    "When asked to 'research X', search the web, then save a short markdown "
    "brief with sources. Keep filenames lowercase-hyphenated."
)

def run_agent(user_query: str, max_iterations: int = 10) -> str:
    messages = [{"role": "user", "content": user_query}]
    print(f"User: {user_query}\n")

    for i in range(max_iterations):
        response = client.messages.create(
            model="claude-sonnet-4-6",
            max_tokens=2048,
            system=SYSTEM,
            messages=messages,
            tools=tools,
        )

        if response.stop_reason != "tool_use":
            text = "".join(b.text for b in response.content if hasattr(b, "text"))
            print(f"Agent (final): {text}")
            return text

        messages.append({"role": "assistant", "content": response.content})
        tool_results = []
        for block in response.content:
            if block.type == "tool_use":
                print(f"  [{i+1}] {block.name}({json.dumps(block.input)[:120]})")
                try:
                    result = available_functions[block.name](**block.input)
                except Exception as e:
                    result = f"Error: {e}"
                tool_results.append({
                    "type": "tool_result",
                    "tool_use_id": block.id,
                    "content": str(result),
                })
        messages.append({"role": "user", "content": tool_results})

    return "(max iterations reached)"

# %% [markdown]
# ## Step 5: Research Assistant in Action
#
# Now we hand the agent a real research task. It should search, then write a brief into the workspace.

# %%
run_agent(
    "Research what the Model Context Protocol is and why it matters. "
    "Save a short markdown brief to research/mcp-brief.md with 3-5 bullet points and a sources list."
)
# Out:
# User: Research what the Model Context Protocol is and why it matters. Save a short markdown brief to research/mcp-brief.md with 3-5 bullet points and a sources list.
#
#   [1] web_search({"query": "Model Context Protocol what is it explained", "max_results": 5})
#   [1] web_search({"query": "Model Context Protocol why it matters AI development", "max_results": 5})
#   [2] write_file({"path": "research/mcp-brief.md", "content": "# Model Context Protocol (MCP) \u2014 Research Brief\n\n## What It Is\nThe)
# Agent (final): Done! Here's a summary of what was saved to **`research/mcp-brief.md`**:
#
# ---
#
# ### 🗂️ Model Context Protocol (MCP) — Brief Summary
#
# **What it is:** An open standard launched by Anthropic in November 2024 to standardize how LLMs connect to external tools, data sources, and services.
#
# **5 Key Takeaways:**
# 1. **Universal adapter for AI** — like USB-C, one protocol connects any model to any tool, eliminating custom integrations.
# 2. **Client–server architecture** — hosts (apps/IDEs) connect to MCP servers that expose tools, resources, and prompts for two-way communication.
# 3. **Model-agnostic** — works with any LLM, not just Anthropic's Claude.
# 4. **Solves the context bottleneck** — gives models reliable, structured access to live data at the right time.
# 5. **Cuts developer complexity** — unified interface means faster builds and easy swapping of models or tools.
#
# **Why it matters:** MCP is seen as foundational infrastructure for real-world AI agent orchestration — moving the ecosystem from fragile, one-off integrations to composable, interoperable systems.
#
# Sources from Wikipedia, Anthropic's official blog, modelcontextprotocol.io, Streamkap, and LinkedIn are included in the file.
# "Done! Here's a summary of what was saved to **`research/mcp-brief.md`**:\n\n---\n\n### 🗂️ Model Context Protocol (MCP) — Brief Summary\n\n**What it is:** An open standard launched by Anthropic in November 2024 to standardize how LLMs connect to external tools, data sources, and services.\n\n**5 Key Takeaways:**\n1. **Universal adapter for AI** — like USB-C, one protocol connects any model to any tool, eliminating custom integrations.\n2. **Client–server architecture** — hosts (apps/IDEs) connect to MCP servers that expose tools, resources, and prompts for two-way communication.\n3. **Model-agnostic** — works with any LLM, not just Anthropic's Claude.\n4. **Solves the context bottleneck** — gives models reliable, structured access to live data at the right time.\n5. **Cuts developer complexity** — unified interface means faster builds and easy swapping of models or tools.\n\n**Why it matters:** MCP is seen as foundational infrastructure for real-world AI agent orchestration — moving the ecosystem from fragile, one-off integrations to composable, interoperable systems.\n\nSources from Wikipedia, Anthropic's official blog, modelcontextprotocol.io, Streamkap, and LinkedIn are included in the file."

# %%
# Inspect what the agent produced
print(list_files("."))
print("\n---\n")
print(read_file("research/mcp-brief.md"))
# Out:
# hello.md
# research
# research/mcp-brief.md
#
# ---
#
# # Model Context Protocol (MCP) — Research Brief
#
# ## What It Is
# The **Model Context Protocol (MCP)** is an open standard and open-source framework introduced by **Anthropic in November 2024**. It standardizes the way AI systems (like large language models) integrate with and share data from external tools, services, and data sources.
#
# ## Key Points
#
# - **Universal "plug-and-play" standard for AI:** MCP acts like a universal adapter — similar to USB-C for hardware — allowing any LLM-powered application to connect to any data source or tool through one consistent protocol, eliminating the need for custom, one-off integrations.
#
# - **Client–server architecture:** MCP defines *hosts* (e.g., Claude Desktop, Cursor IDE) that connect to *MCP servers*, which expose tools, resources, and prompts. This two-way, secure communication lets models both retrieve context *and* execute actions in external systems.
#
# - **Model-agnostic by design:** Although created by Anthropic, MCP works with any LLM that implements the client protocol, making it a true open standard rather than a proprietary lock-in mechanism.
#
# - **Solves the "context bottleneck":** The critical challenge in production AI is not model capability, but reliably feeding models the *right information at the right time*. MCP addresses this by giving LLMs structured, controlled access to live data from databases, APIs, file systems, and business tools.
#
# - **Reduces developer complexity and accelerates adoption:** By providing a unified interface, MCP cuts development time for building or integrating AI agents, enables faster ecosystem growth, and allows teams to swap models or tools without rebuilding integrations from scratch.
#
# ## Why It Matters
# MCP shifts AI development from brittle, bespoke integrations toward a composable ecosystem — one where agents, tools, and data sources interoperate freely. It is widely considered a foundational step toward reliable, real-world AI orchestration.
#
# ---
#
# ## Sources
# 1. **Wikipedia** — Model Context Protocol overview: https://en.wikipedia.org/wiki/Model_Context_Protocol
# 2. **Anthropic (Official Announcement)** — Introducing the Model Context Protocol: https://www.anthropic.com/news/model-context-protocol
# 3. **modelcontextprotocol.io** — Official MCP documentation: https://modelcontextprotocol.io/
# 4. **Streamkap** — MCP Explained (model-agnostic, infrastructure strategy): https://streamkap.com/resources-and-guides/model-context-protocol-explained
# 5. **LinkedIn / Krishnan R.** — Bridging the gap between LLMs and real-world tools: https://www.linkedin.com/pulse/anthropics-model-context-protocol-mcp-bridging-gap-llms-krishnan-r-f43oc

# %% [markdown]
# ## Step 6: A Reorganization Task
#
# Anything an agent can save, it can also rearrange. Watch it use `move_file`, `edit_file`, and `delete_file`.

# %%
run_agent(
    "Rename research/mcp-brief.md to notes/mcp.md, add a '## TL;DR' section at the top, "
    "and delete the empty research/ folder contents if any."
)
# Out:
# User: Rename research/mcp-brief.md to notes/mcp.md, add a '## TL;DR' section at the top, and delete the empty research/ folder contents if any.
#
#   [1] list_files({"directory": "research"})
#   [1] list_files({"directory": "notes"})
#   [1] read_file({"path": "research/mcp-brief.md"})
#   [2] move_file({"src": "research/mcp-brief.md", "dst": "notes/mcp.md"})
#   [3] edit_file({"path": "notes/mcp.md", "old": "# Model Context Protocol (MCP) \u2014 Research Brief", "new": "# Model Context Protocol)
# Agent (final): All done! Here's a summary of every change made:
#
# | Action | Detail |
# |---|---|
# | 📁 **Moved** | `research/mcp-brief.md` → `notes/mcp.md` |
# | ✏️ **Added** | `## TL;DR` section at the top of `notes/mcp.md` |
# | 🗑️ **Cleaned up** | `research/` had only `mcp-brief.md` (now moved), so it's effectively empty — no other files to delete |
#
# The `## TL;DR` section reads:
# > *MCP is an open standard by Anthropic (Nov 2024) that gives any LLM a single, consistent way to connect to external tools, APIs, and data sources — eliminating one-off integrations and solving the context bottleneck in production AI.*
# "All done! Here's a summary of every change made:\n\n| Action | Detail |\n|---|---|\n| 📁 **Moved** | `research/mcp-brief.md` → `notes/mcp.md` |\n| ✏️ **Added** | `## TL;DR` section at the top of `notes/mcp.md` |\n| 🗑️ **Cleaned up** | `research/` had only `mcp-brief.md` (now moved), so it's effectively empty — no other files to delete |\n\nThe `## TL;DR` section reads:\n> *MCP is an open standard by Anthropic (Nov 2024) that gives any LLM a single, consistent way to connect to external tools, APIs, and data sources — eliminating one-off integrations and solving the context bottleneck in production AI.*"

# %% [markdown]
# ## Key Takeaways
#
# 1. **Tool calling** is just Claude emitting structured `tool_use` blocks given JSON-schema tool definitions.
# 2. **Tool execution** happens on *our* side — we run the function and pass results back as `tool_result` blocks.
# 3. **The agent loop** is small: keep calling Claude with the growing message history until `stop_reason != "tool_use"`.
# 4. **Same use case forward** — in demo `01` we'll wrap these exact tools as an **MCP server** so any host (Claude Desktop, our own client, the Agent SDK) can use them. In demo `02` we rebuild the agent loop on the **Claude Agent SDK** and plug the MCP server in.
#
# ### What MCP will buy us
#
# Right now the tools and the agent live in the same Python file. That's fine for a notebook, but it doesn't scale: every new client has to reimplement the tools. MCP standardizes this — *one* server, *many* hosts.
